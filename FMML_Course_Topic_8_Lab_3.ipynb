# %% [markdown]
# <a href="https://colab.research.google.com/github/Prudhvi2k3/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-04 04:13:16--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   124MB/s    in 0.6s
#
# 2023-05-04 04:13:17 (124 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 16415  1702.03525v2  There has been relatively little attention to ...    cs
# 31122  1802.03943v1  This paper introduces an universal and structu...    cs
# 22179  1506.07997v1  Finding statistically significant high-order i...  stat
# 10416   1306.4650v2  Majorization-minimization algorithms consist o...  stat
# 7553   1802.03300v1  A recommender system based on ranks is propose...  stat
# ...             ...                                                ...   ...
# 8124    1207.4089v1  Textures often show multiscale properties and ...    cs
# 32956  1511.06964v7  Two novel deep hybrid architectures, the Deep ...    cs
# 1622   1609.08441v2  PLDA is a popular normalization approach for t...    cs
# 21598   1108.2228v3  We present a method to estimate block membersh...  stat
# 7519   1801.10193v1  The identification of novel drug-target (DT) i...  stat
#
#                                                    title  year  \
# 16415  Learning to Parse and Translate Improves Neura...  2017
# 31122  Temporal and Volumetric Denoising via Quantile...  2018
# 22179  An Efficient Post-Selection Inference on High-...  2015
# 10416  Stochastic Majorization-Minimization Algorithm...  2013
# 7553              Bayesian inference for bivariate ranks  2018
# ...                                                  ...   ...
# 8124   A Two-Stage Combined Classifier in Scale Space...  2012
# 32956  Online Semi-Supervised Learning with Deep Hybr...  2015
# 1622                     Weakly Supervised PLDA Training  2016
# 21598  A consistent adjacency spectral embedding for ...  2011
# 7519   DeepDTA: Deep Drug-Target Binding Affinity Pre...  2018
#
#                                                 keywords
# 16415  [relatively, attention, incorporating, linguis...
# 31122  [introduces, universal, structure, preserving,...
# 22179  [statistically, significant, interaction, pred...
# 10416  [majorization, minimization, algorithms, itera...
# 7553   [recommender, prediction, continuous, variable...
# ...                                                  ...
# 8124   [multiscale, properties, multiscale, technique...
# 32956  [architectures, boltzmann, denoising, supervis...
# 1622   [normalization, delivered, performance, verifi...
# 21598  [membership, generated, stochastic, blockmodel...
# 7519   [identification, interactions, substantial, di...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 16415    [relatively, attention, incorporating, linguis...
# 31122    [introduces, universal, structure, preserving,...
# 22179    [statistically, significant, interaction, pred...
# 10416    [majorization, minimization, algorithms, itera...
# 7553     [recommender, prediction, continuous, variable...
#                                ...
# 7167     [convolutional, approximation, convolution, al...
# 24718    [multilinear, discriminant, recognition, multi...
# 6285     [categorical, supervised, researchers, accurat...
# 13484    [extrusion, manufacturing, productive, improve...
# 3944     [regulated, algorithm, hybridizes, advantageou...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8815 words.
# Out of those 4620 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="66d50901-4a8a-434c-9ec3-50ef71d5e45d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66d50901-4a8a-434c-9ec3-50ef71d5e45d")) {                    Plotly.newPlot(                        "66d50901-4a8a-434c-9ec3-50ef71d5e45d",                        [{"x":["incorporating","constrained","combining","encourages","effectiveness","relatively","translation","incorporate","afterward","recurrent","experiments","extensive","linguistic","attention","considering","translate","preserving","multipliers","variational","efficient","resolution","frequency","optimization","universal","performance","modalities","framework","alternating","linearization","volumetric","demonstrate","characteristics","structure","direction","denoising","regularization","coherence","tomography","excellent","introduces","emphasize","inherently","dimensional","algorithm","introducing","experimental","significant","distributions","inferences","covariates","guaranteed","challenging","predictive","advancements","computing","inference","underlying","screening","identifying","reasonable","influence","challenge","increasing","important","extremely","candidates","difficulty","computational","literature","statistical","applications","presented","selection","algorithmic","receiving","statistically","interaction","regression","iterations","statistics","converges","assumptions","minimization","majorization","structured","stationary","minimizing","programming","algorithms","convergence","iteratively","estimation","processing","factorization","introduce","surrogate","functions","simplicity","principle","objective","stochastic","applicability","majorizing","experimentally","recommender","modelling","conditional","continuous","parameter","corresponding","dependence","prediction","providing","variables","parametric","approximation","predicted","bivariate","movielens","benchmark","posterior","incomplete","approximate","distribution","accelerates","trainable","connection","demonstrating","perspective","strengths","integrate","different","extensively","combination","significantly","connecting","particular","accelerated","reformulates","reference","evaluated","occlusion","limitations","densities","representation","robustness","information","convolution","leverages","sequentially","convolutional","revisited","transient","temporally","augmenting","challenges","classification","complexity","techniques","illustrate","particularly","informative","databases","discarding","heuristics","streaming","generating","unforeseen","ubiquitous","collection","favourably","practical","mechanism","challenged","representing","expressiveness","categorical","descriptive","preliminary","formalism","complicated","constructs","discusses","knowledge","automated","efficiency","sensitive","phenomena","variations","potential","uncertain","hierarchy","containing","treatment","equivalent","justified","processes","marginalization","typically","likelihood"],"y":[75,71,106,12,184,64,103,63,1,136,617,166,74,185,56,14,63,14,59,400,120,56,318,41,858,41,543,30,4,16,554,95,325,57,46,84,14,21,26,64,7,19,193,836,59,396,222,125,12,4,31,265,61,1,136,222,96,13,93,33,61,146,92,333,52,29,43,293,104,169,458,168,160,40,5,24,80,124,26,57,25,63,62,1,93,42,49,129,580,108,34,199,290,37,339,17,216,30,56,163,138,40,1,51,16,50,95,108,124,121,23,211,78,118,51,135,37,4,1,199,44,33,108,209,3,21,33,36,59,23,47,801,38,133,267,16,263,14,2,56,141,44,66,16,343,95,706,50,22,15,383,3,5,16,14,120,509,216,387,70,72,29,72,1,40,17,103,2,21,80,2,122,105,5,71,6,11,5,54,28,34,19,31,349,116,166,63,35,75,168,27,35,49,30,60,8,123,5,101,76],"type":"bar"},{"x":["incorporating","constrained","combining","encourages","effectiveness","relatively","translation","incorporate", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4620,), (4620, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7775

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Unit</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>Commitment</span> <span style=''>using</span> <span style=''>Nearest</span> <span style=''>Neighbor</span> <span style=''>as</span> <span style=''>a</span> <span style=''>Short</span> <span style=''>Term</span> <span style=''>Proxy</span> <br/><br/><span style=''>We</span> <span style=''>devise</span> <span style=''>the</span> <span style=''>Unit</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>Commitment</span> <span style=''>Nearest</span> <span style=''>Neighbor</span> <span style=''>(UCNN)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>be</span> <span style=''>used</span> <span style=''>as</span> <span style=''>a</span> <span style=''>proxy</span> <span style=''>for</span> <span style=''>quickly</span> <span style='background-color:rgba(255, 0, 0, 0.5185185185185184);'>approximating</span> <span style=''>outcomes</span> <span style=''>of</span> <span style=''>short</span> <span style=''>term</span> <span style='background-color:rgba(0, 255, 0, 0.34939759036144585);'>decisions</span> <span style=''>to</span> <span style=''>make</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>long</span> <span style=''>term</span> <span style='background-color:rgba(0, 255, 0, 0.42465753424657526);'>assessment</span> <span style=''>and</span> <span style=''>planning</span> <span style=''>for</span> <span style=''>large</span> <span style=''>power</span> <span style=''>systems</span> <span style='background-color:rgba(0, 255, 0, 0.35153583617747436);'>Experimental</span> <span style=''>results</span> <span style=''>on</span> <span style=''>updated</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>IEEE</span> <span style=''>RTS79</span> <span style=''>and</span> <span style=''>IEEE</span> <span style=''>RTS96</span> <span style=''>show</span> <span style=''>high</span> <span style=''>accuracy</span> <span style=''>measured</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.6923076923076923);'>operational</span> <span style=''>cost</span> <span style=''>achieved</span> <span style=''>in</span> <span style=''>runtimes</span> <span style=''>that</span> <span style=''>are</span> <span style=''>lower</span> <span style=''>in</span> <span style=''>several</span> <span style=''>orders</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>magnitude</span> <span style=''>than</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.39007092198581556);'>traditional</span> <span style=''>approach</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Marginal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>for</span> <span style=''>doubly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style=''>models</span> <br/><br/><span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>for</span> <span style=''>models</span> <span style=''>that</span> <span style=''>have</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partition</span> <span style=''>function</span> <span style=''>is</span> <span style=''>known</span> <span style=''>as</span> <span style=''>a</span> <span style=''>doubly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style=''>problem</span> <span style=''>where</span> <span style=''>standard</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>The</span> <span style=''>past</span> <span style=''>decade</span> <span style=''>has</span> <span style=''>seen</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>development</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>auxiliary</span> <span style=''>variable</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>(Moller</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2006</span> <span style=''>Murray</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2006)</span> <span style=''>for</span> <span style=''>tackling</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>being</span> <span style=''>members</span> <span style=''>of</span> <span style=''>the</span> <span style=''>more</span> <span style=''>general</span> <span style=''>class</span> <span style=''>of</span> <span style=''>pseudo</span> <span style=''>marginal</span> <span style=''>or</span> <span style=''>exact</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>(Andrieu</span> <span style=''>and</span> <span style=''>Roberts</span> <span style=''>2009)</span> <span style=''>which</span> <span style=''>make</span> <span style=''>use</span> <span style=''>of</span> <span style=''>unbiased</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posteriors</span> <span style=''>Everitt</span> <span style=''>et</span> <span style=''>al</span> <span style=''>(2017)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigated</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>exact</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>sampling</span> <span style=''>(IS)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>(SMC)</span> <span style=''>in</span> <span style=''>doubly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style=''>problems</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Infinite</span> <span style=''>Tucker</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Decomposition</span> <span style='background-color:rgba(255, 0, 0, 0.7723577235772358);'>Nonparametric</span> <span style=''>Bayesian</span> <span style=''>Models</span> <span style=''>for</span> <span style=''>Multiway</span> <span style=''>Data</span> <span style=''>Analysis</span> <br/><br/><span style=''>Tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>is</span> <span style=''>a</span> <span style=''>powerful</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>tool</span> <span style=''>for</span> <span style=''>multiway</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>Many</span> <span style=''>popular</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>Tucker</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>CANDECOMPPARAFAC</span> <span style=''>(CP)</span> <span style=''>amount</span> <span style=''>to</span> <span style=''>multi</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.4218750000000001);'>factorization</span> <span style=''>They</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>insufficient</span> <span style=''>to</span> <span style=''>model</span> <span style=''>(i)</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interactions</span> <span style=''>between</span> <span style=''>data</span> <span style=''>entities</span> <span style=''>(ii)</span> <span style=''>various</span> <span style=''>data</span> <span style=''>types</span> <span style=''>(eg</span> <span style=''>missing</span> <span style=''>data</span> <span style=''>and</span> <span style=''>binary</span> <span style=''>data)</span> <span style=''>and</span> <span style=''>(iii)</span> <span style=''>noisy</span> <span style='background-color:rgba(255, 0, 0, 0.36150234741784043);'>observations</span> <span style=''>and</span> <span style=''>outliers</span> <span style=''>To</span> <span style=''>address</span> <span style=''>these</span> <span style=''>issues</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>tensor</span> <span style=''>variate</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.7723577235772358);'>nonparametric</span> <span style=''>Bayesian</span> <span style=''>models</span> <span style=''>coupled</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>multiway</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>We</span> <span style=''>name</span> <span style=''>these</span> <span style=''>models</span> <span style=''>InfTucker</span> <span style=''>Using</span> <span style=''>these</span> <span style=''>InfTucker</span> <span style=''>we</span> <span style=''>conduct</span> <span style=''>Tucker</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>in</span> <span style=''>an</span> <span style=''>infinite</span> <span style=''>feature</span> <span style=''>space</span> <span style=''>Unlike</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>models</span> <span style=''>our</span> <span style=''>new</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computation</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Parameters</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Differential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Equations</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>(ABC)</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>method</span> <span style=''>provides</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comprehensive</span> <span style=''>platform</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitivity</span> <span style=''>analysis</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equations</span> <span style=''>However</span> <span style=''>this</span> <span style=''>method</span> <span style=''>like</span> <span style=''>other</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>methods</span> <span style=''>incurs</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>as</span> <span style=''>it</span> <span style=''>requires</span> <span style=''>explicit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integration</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equations</span> <span style=''>to</span> <span style=''>carry</span> <span style=''>out</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>circumventing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requirement</span> <span style=''>of</span> <span style=''>explicit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integration</span> <span style=''>by</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>derivatives</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>to</span> <span style=''>smooth</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>from</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>We</span> <span style=''>evaluate</span> <span style=''>our</span> <span style=''>methods</span> <span style=''> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12111581920903955)
# 	knowledge (0.12323446327683615)
# 	experimental (0.13983050847457626)
# 	architecture (0.08862994350282485)
# 	segmentation (0.07274011299435028)
# 	information (0.24929378531073446)
# 	detection (0.13029661016949154)
# 	convolutional (0.1352401129943503)
# 	recognition (0.134180790960452)
# 	different (0.2828389830508475)
#
# Some Statistics words are:
# 	stochastic (0.13211382113821138)
# 	statistical (0.15345528455284552)
# 	theoretical (0.15497967479674796)
# 	variables (0.14126016260162602)
# 	algorithm (0.3978658536585366)
# 	distribution (0.18241869918699186)
# 	estimation (0.18292682926829268)
# 	inference (0.19817073170731708)
# 	dimensional (0.18902439024390244)
# 	regression (0.1915650406504065)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7f492b5e-0629-4406-96f8-3732abe2cbc4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f492b5e-0629-4406-96f8-3732abe2cbc4")) {                    Plotly.newPlot(                        "7f492b5e-0629-4406-96f8-3732abe2cbc4",                        [{"x":["incorporating","constrained","combining","encourages","effectiveness","relatively","translation","incorporate","afterward","recurrent","experiments","extensive","linguistic","attention","considering","translate","preserving","multipliers","variational","efficient","resolution","frequency","optimization","universal","performance","modalities","framework","alternating","linearization","volumetric","demonstrate","characteristics","structure","direction","denoising","regularization","coherence","tomography","excellent","introduces","emphasize","inherently","dimensional","algorithm","introducing","experimental","significant","distributions","inferences","covariates","guaranteed","challenging","predictive","advancements","computing","inference","underlying","screening","identifying","reasonable","influence","challenge","increasing","important","extremely","candidates","difficulty","computational","literature","statistical","applications","presented","selection","algorithmic","receiving","statistically","interaction","regression","iterations","statistics","converges","assumptions","minimization","majorization","structured","stationary","minimizing","programming","algorithms","convergence","iteratively","estimation","processing","factorization","introduce","surrogate","functions","simplicity","principle","objective","stochastic","applicability","majorizing","experimentally","recommender","modelling","conditional","continuous","parameter","corresponding","dependence","prediction","providing","variables","parametric","approximation","predicted","bivariate","movielens","benchmark","posterior","incomplete","approximate","distribution","accelerates","trainable","connection","demonstrating","perspective","strengths","integrate","different","extensively","combination","significantly","connecting","particular","accelerated","reformulates","reference","evaluated","occlusion","limitations","densities","representation","robustness","information","convolution","leverages","sequentially","convolutional","revisited","transient","temporally","augmenting","challenges","classification","complexity","techniques","illustrate","particularly","informative","databases","discarding","heuristics","streaming","generating","unforeseen","ubiquitous","collection","favourably","practical","mechanism","challenged","representing","expressiveness","categorical","descriptive","preliminary","formalism","complicated","constructs","discusses","knowledge","automated","efficiency","sensitive","phenomena","variations","potential","uncertain","hierarchy","containing","treatment","equivalent","justified","processes","marginalization","typically","likelihood","multivariate","application","conditioned","conditioning","properties","integrated","technique","successful","geostatistical","simulation","perceptual","adversarial","reservoir","evaluation","contribution","generation","unconditional","represent","discriminator","generative","differentiable","simulations","workflows","constrain","supervised","discriminate","embeddings","implemented","difficult","libraries","maintaining","similarly","computationally","integrating","processors","optimizing","architectures","consumption","primitives","implementing","addressed","frameworks","implementation","workloads","intensive","consuming","optimized","researchers","analogous","implementations","community","subroutines","platforms","intervening","bidirectional","available","transition","monitor ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	geostatistical
# 	inversions
# 	precisions
# 	autocorrelation
# 	initializing
# 	unintentionally
# 	inductively
# 	operationally
# 	parametrizations
# 	dispersion
# 	penalizations
# 	sparsistent
# 	barycenters
# 	reparameterizing
# 	robustification
# 	tibshirani
# 	envelopes
# 	correntropy
# 	unmeasured
# 	nomination
# Some words which never appear in Statistics papers:
# 	volumetric
# 	reformulates
# 	credibility
# 	sequenced
# 	traversing
# 	annotating
# 	functionally
# 	machining
# 	formalisms
# 	inheritance
# 	metaheuristic
# 	multiobjective
# 	metaheuristics
# 	personnel
# 	maliciously
# 	genotypes
# 	phonology
# 	logically
# 	narrative
# 	intelligences

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0358227079538556e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7233333333333334
